# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisManuelCatzoliSoriano/EDP-I/blob/main/M%C3%A9tododeGaussSiedel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Definimos la matriz A y el vector b
A = np.array([[10, -1, 2, 0],
              [-1, 11, -1, 3],
              [2, -1, 10, -1],
              [0, 3, -1, 8]], dtype=float)

b = np.array([6, 25, -11, 15], dtype=float)

# Tolerancia y número máximo de iteraciones
tol = 1e-6
max_iter = 100

# Condición inicial
x = np.zeros_like(b)

# Guardar resultados para la tabla
resultados = []

# Método de Gauss-Seidel
for k in range(max_iter):
    x_new = np.copy(x)
    for i in range(len(b)):
        suma = 0
        for j in range(len(b)):
            if j != i:
                suma += A[i, j] * x_new[j]
        x_new[i] = (b[i] - suma) / A[i, i]

    # Guardar la iteración y valores
    resultados.append([k+1] + list(x_new))

    # Criterio para parar
    if np.linalg.norm(x_new - x, ord=np.inf) < tol:
        break

    x = x_new

# Crear una tabla con los resultados
columnas = ["Iteración"] + [f"x{i+1}" for i in range(len(b))]
tabla = pd.DataFrame(resultados, columns=columnas)

print("Resultados del método de Gauss-Seidel:")
display(tabla)
# Out:
# Resultados del método de Gauss-Seidel:
#    Iteración        x1        x2        x3        x4
# 0          1  0.600000  2.327273 -0.987273  0.878864
# 1          2  1.030182  2.036938 -1.014456  0.984341
# 2          3  1.006585  2.003555 -1.002527  0.998351
# 3          4  1.000861  2.000298 -1.000307  0.999850
# 4          5  1.000091  2.000021 -1.000031  0.999988
# 5          6  1.000008  2.000001 -1.000003  0.999999
# 6          7  1.000001  2.000000 -1.000000  1.000000
# 7          8  1.000000  2.000000 -1.000000  1.000000
