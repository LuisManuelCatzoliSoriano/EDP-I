# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisManuelCatzoliSoriano/EDP-I/blob/main/M%C3%A9tododeGaussSiedel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Definimos la matriz A y el vector b
A = np.array([[4, -1, -1, 0],
              [-1, 4, 0, -1],
              [-1, 0, 4, -1],
              [0, -1, -1, 4]], dtype=float)

b = np.array([0, 2/3, 8/9, 14/9], dtype=float)

# Tolerancia y número máximo de iteraciones
tol = 1e-6
max_iter = 100

# Condición inicial
x = np.zeros_like(b)

# Guarda resultados para la tabla
resultados = []

# Método de Gauss-Seidel
for k in range(max_iter):
    x_new = np.copy(x)
    for i in range(len(b)):
        suma = 0
        for j in range(len(b)):
            if j != i:
                suma += A[i, j] * x_new[j]
        x_new[i] = (b[i] - suma) / A[i, i]

    # Guarda la iteración y valores
    resultados.append([k+1] + list(x_new))

    # Criterio para parar
    if np.linalg.norm(x_new - x, ord=np.inf) < tol:
        break

    x = x_new

# Crea una tabla con los resultados
columnas = ["Iteración"] + [f"x{i+1}" for i in range(len(b))]
tabla = pd.DataFrame(resultados, columns=columnas)

print("Resultados del método de Gauss-Seidel:")
display(tabla)
# Out:
# Resultados del método de Gauss-Seidel:
#     Iteración        x1        x2        x3        x4
# 0           1  0.000000  0.166667  0.222222  0.486111
# 1           2  0.097222  0.312500  0.368056  0.559028
# 2           3  0.170139  0.348958  0.404514  0.577257
# 3           4  0.188368  0.358073  0.413628  0.581814
# 4           5  0.192925  0.360352  0.415907  0.582954
# 5           6  0.194065  0.360921  0.416477  0.583238
# 6           7  0.194350  0.361064  0.416619  0.583310
# 7           8  0.194421  0.361099  0.416655  0.583327
# 8           9  0.194439  0.361108  0.416664  0.583332
# 9          10  0.194443  0.361110  0.416666  0.583333
# 10         11  0.194444  0.361111  0.416666  0.583333
# 11         12  0.194444  0.361111  0.416667  0.583333
