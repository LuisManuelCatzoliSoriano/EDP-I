# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisManuelCatzoliSoriano/EDP-I/blob/main/M%C3%A9tododeJacobi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Definimos la matriz A y el vector b
A = np.array([[10, -1, 2, 0],
              [-1, 11, -1, 3],
              [2, -1, 10, -1],
              [0, 3, -1, 8]], dtype=float)

b = np.array([6, 25, -11, 15], dtype=float)

# Tolerancia y número máximo de iteraciones
tol = 1e-6
max_iter = 100

# Condición inicial
x = np.zeros_like(b)

# Guardar resultados para la tabla
resultados = []

# Método de Jacobi
for k in range(max_iter):
    x_new = np.zeros_like(x)
    for i in range(len(b)):
        suma = 0
        for j in range(len(b)):
            if j != i:
                suma += A[i, j] * x[j]
        x_new[i] = (b[i] - suma) / A[i, i]

    # Guardar la iteración y valores
    resultados.append([k+1] + list(x_new))

    # Criterio para parar
    if np.linalg.norm(x_new - x, ord=np.inf) < tol:
        break

    x = x_new

# Crea una tabla con los resultados
columnas = ["Iteración"] + [f"x{i+1}" for i in range(len(b))]
tabla = pd.DataFrame(resultados, columns=columnas)

print("Resultados del método de Jacobi:")
display(tabla)
# Out:
# Resultados del método de Jacobi:
#     Iteración        x1        x2        x3        x4
# 0           1  0.600000  2.272727 -1.100000  1.875000
# 1           2  1.047273  1.715909 -0.805227  0.885227
# 2           3  0.932636  2.053306 -1.049341  1.130881
# 3           4  1.015199  1.953696 -0.968109  0.973843
# 4           5  0.988991  2.011415 -1.010286  1.021351
# 5           6  1.003199  1.992241 -0.994522  0.994434
# 6           7  0.998128  2.002307 -1.001972  1.003594
# 7           8  1.000625  1.998670 -0.999036  0.998888
# 8           9  0.999674  2.000448 -1.000369  1.000619
# 9          10  1.000119  1.999768 -0.999828  0.999786
# 10         11  0.999942  2.000085 -1.000068  1.000109
# 11         12  1.000022  1.999959 -0.999969  0.999960
# 12         13  0.999990  2.000016 -1.000013  1.000019
# 13         14  1.000004  1.999993 -0.999994  0.999992
# 14         15  0.999998  2.000003 -1.000002  1.000003
# 15         16  1.000001  1.999999 -0.999999  0.999999
# ...
